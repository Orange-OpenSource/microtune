# %% [markdown]
# # Load a model and its metadata from a pickle file

# %%
mfile = "../output/E16_1_04-opt_ppo_n_arms_disq/agent-T6S0-SB3PPO_-10_10C-best.pickle"

# %%
import sys
sys.path.append('..')

from pkg.policy_sb3 import SB3PolicyPPO

policy = SB3PolicyPPO()

policy.load(filepath="../output/E16_1_04-opt_ppo_n_arms", filever="agent-T6S0", verbose=100, dftext="-best.pickle")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       4 from pkg.policy_sb3 import SB3PolicyPPO
#       6 agent = SB3PolicyPPO()
# ----> 8 agent.load(filepath="../output/E16_1_04-opt_ppo_n_arms", filever="agent-T6S0", verbose=100, dftext="-best.pickle")
#
# AttributeError: 'SB3PolicyPPO' object has no attribute 'load'
